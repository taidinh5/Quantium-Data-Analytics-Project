# %% [markdown]
# <a href="https://www.kaggle.com/code/taidinh5/qvi-data-analytics-task-three?scriptVersionId=255518268" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <h1 style="font-family:verdana; font-weight:bold;""> <center> Quantium Virtual Internship: Task Three </center> </h1>
# <p><center font-family:cursive;">Author: Tai Dinh</center></p>
#
# ***

# %% [markdown]
# <div style="height:5px; background-color:#0096FF;"></div>

# %% [markdown]
# <h2 style="font-family:verdana; font-weight: bold;""> 1. Background Information  </h2>
#
# <div style="background-color:#f0f8ff; padding:15px; border-left:5px solid #0096FF; font-family:Verdana; font-size:14px;">
#   <b>🖼️ Business Objective:</b><br>
#   As part of Quantium’s Retail Analytics Team, it is time to send a report to Julia, based on our analytics from the previous tasks. We want to provide her with insights and recommendations that she can use when developing the strategic plan for the next half year.
# </div>

# %% [markdown]
# <div style="height:5px; background-color:#0096FF;"></div>

# %% [markdown]
# <h2 style="font-family:verdana; font-weight: bold;""> 2. Presentation Report  </h2>

# %% [markdown]
# ![775FC9FE-612E-4B8A-8C7A-4ACC57B587C9-min-min (1) (1) (1).png](attachment:fb6dbc5d-7da0-4020-84d0-a9eef1cd1998.png)

# %% [markdown]
# ![DEC8C4C4-42E1-4D76-BB76-6D003F2F1880-min-min.png](attachment:10bf9c28-a08d-496c-9b99-be9426baf394.png)

# %% [markdown]
# ![0FA3EC5F-0614-41E2-A2F2-321699BC2ECC-min-min.png](attachment:2340e183-97d7-4890-81b6-5538be04ae91.png)

# %% [markdown]
# ![F6EBA047-726A-4AF8-B907-6CD21AEA29C9-min-min.png](attachment:5aab42fd-2725-4100-999f-0f71545222f5.png)

# %% [markdown]
# ![{6D0FB17E-8958-41AC-9651-5179AC2A3B9E}-min.png](attachment:fbbf37c3-e62e-4234-bc49-6d6770b3f901.png)

# %% [markdown]
# ![{A7EF7F28-0FA1-4481-A96D-B9061DFE8C75}-min.png](attachment:ab3ae50c-606a-4c67-964d-adbfd255b2a4.png)

# %% [markdown]
# ![{B4D967D0-0E6F-4585-A37A-F6CE1E186160}-min.png](attachment:46058165-52fa-481b-921a-baf6514a50c6.png)

# %% [markdown]
# ![{8D8EC447-AA9D-4A4E-ACF4-16FBEBBB6696}-min.png](attachment:71982f77-ca72-451b-9cd0-3a672849c9c3.png)

# %% [markdown]
# ![{8A26E138-4055-477C-8BE2-56381D915286}-min.png](attachment:15cda9d0-1fd5-4956-9285-5393203aa9fd.png)

# %% [markdown]
# ![{287563DC-955D-490E-9D94-C724E007BE86}-min.png](attachment:76c00b93-8df3-449b-8cd7-50bad68fa989.png)

# %% [markdown]
# ![{2ABE333A-1156-44BF-9C29-D2B4FE66E0F3}-min.png](attachment:a87d4ad3-e911-412b-a7d8-c1c9356ab717.png)

# %% [markdown]
# ![{FBE13E51-0C96-48AD-A93E-28840BE5AEC6}-min.png](attachment:d8430cd3-45e3-45e0-a0bc-9fbe3ebcd902.png)

# %% [markdown]
# ![{F28D7B35-D9F4-4ADF-8A2E-75B43AAD5374}-min.png](attachment:8e5aa8f0-bd90-40e0-a73f-7d2847d32507.png)

# %% [markdown]
# ![{97776396-F2B4-44F9-80F3-879F633822A9}-min.png](attachment:406072fc-fbe4-4a82-a931-24d349f24a0b.png)

# %% [markdown]
# ![{A4B802FA-1DD6-480E-B59D-DCE8E917479B}-min.png](attachment:59079769-5512-4932-b896-5bbf2bb80480.png)
